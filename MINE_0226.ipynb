# %% [markdown]
# <a href="https://colab.research.google.com/github/dolmani38/concept_drift/blob/main/MINE_0226.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #MINE

# %%
import numpy as np
import pandas as pd
import torch
from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
data_size = 20000
cor = [0.5, 1, 1.5, 2.5, 3]

# %%
y= np.random.normal(1,2,data_size)
x = np.zeros((data_size,6))
for ix,cor_ in enumerate(cor):
    x[:,ix] = y + np.random.normal(1,cor_,data_size)
    sns.scatterplot(x=x[:,ix],y=y)

# %%
for i in range(200):
    os = i*100
    x[os:os+100,4] = y[os:os+100] + np.random.normal(1,1+(i/100),100)
    x[os:os+100,5] = i
sns.scatterplot(x=x[:,4],y=y)
# Out:
# <AxesSubplot:>

# %%
from sklearn.feature_selection import mutual_info_regression

def make_mi_scores(X, y, discrete_features):
    mi_scores = mutual_info_regression(X, y, discrete_features=discrete_features)
    mi_scores = pd.Series(mi_scores, name="MI Scores", index=X.columns)
    mi_scores = mi_scores.sort_values(ascending=False)
    return mi_scores

# %%
mi_scores = make_mi_scores(pd.DataFrame(x,columns=['x0','x1','x2','x3','x4','ix']), y, discrete_features="auto")
print(mi_scores)
# Out:
# x0    1.421132
# x1    0.802937
# x2    0.512152
# x4    0.337485
# x3    0.241595
# ix    0.000000
# Name: MI Scores, dtype: float64

# %%
for i in range(200):
    os = i*100
    mi_scores = make_mi_scores(pd.DataFrame(x[os:os+100,4],columns=['x4']), y[os:os+100], discrete_features="auto")
    print(i, mi_scores)
# Out:
# 0 x4    0.816501
# Name: MI Scores, dtype: float64
# 1 x4    0.770926
# Name: MI Scores, dtype: float64
# 2 x4    0.713256
# Name: MI Scores, dtype: float64
# 3 x4    0.726473
# Name: MI Scores, dtype: float64
# 4 x4    0.799432
# Name: MI Scores, dtype: float64
# 5 x4    0.7121
# Name: MI Scores, dtype: float64
# 6 x4    0.800164
# Name: MI Scores, dtype: float64
# 7 x4    1.011838
# Name: MI Scores, dtype: float64
# 8 x4    0.751324
# Name: MI Scores, dtype: float64
# 9 x4    0.730621
# Name: MI Scores, dtype: float64
# 10 x4    0.914347
# Name: MI Scores, dtype: float64
# 11 x4    0.644721
# Name: MI Scores, dtype: float64
# 12 x4    0.567147
# Name: MI Scores, dtype: float64
# 13 x4    0.72142
# Name: MI Scores, dtype: float64
# 14 x4    0.561236
# Name: MI Scores, dtype: float64
# 15 x4    0.676077
# Name: MI Scores, dtype: float64
# 16 x4    0.601454
# Name: MI Scores, dtype: float64
# 17 x4    0.611601
# Name: MI Scores, dtype: float64
# 18 x4    0.640559
# Name: MI Scores, dtype: float64
# 19 x4    0.631222
# Name: MI Scores, dtype: float64
# 20 x4    0.770703
# Name: MI Scores, dtype: float64
# 21 x4    0.632614
# Name: MI Scores, dtype: float64
# 22 x4    0.588665
# Name: MI Scores, dtype: float64
# 23 x4    0.640904
# Name: MI Scores, dtype: float64
# 24 x4    0.629805
# Name: MI Scores, dtype: float64
# 25 x4    0.599879
# Name: MI Scores, dtype: float64
# 26 x4    0.662491
# Name: MI Scores, dtype: float64
# 27 x4    0.531592
# Name: MI Scores, dtype: float64
# 28 x4    0.62236
# Name: MI Scores, dtype: float64
# 29 x4    0.462026
# Name: MI Scores, dtype: float64
# 30 x4    0.715999
# Name: MI Scores, dtype: float64
# 31 x4    0.485817
# Name: MI Scores, dtype: float64
# 32 x4    0.611277
# Name: MI Scores, dtype: float64
# 33 x4    0.587595
# Name: MI Scores, dtype: float64
# 34 x4    0.695326
# Name: MI Scores, dtype: float64
# 35 x4    0.381105
# Name: MI Scores, dtype: float64
# 36 x4    0.517758
# Name: MI Scores, dtype: float64
# 37 x4    0.504152
# Name: MI Scores, dtype: float64
# 38 x4    0.52096
# Name: MI Scores, dtype: float64
# 39 x4    0.474062
# Name: MI Scores, dtype: float64
# 40 x4    0.567827
# Name: MI Scores, dtype: float64
# 41 x4    0.659564
# Name: MI Scores, dtype: float64
# 42 x4    0.494594
# Name: MI Scores, dtype: float64
# 43 x4    0.620696
# Name: MI Scores, dtype: float64
# 44 x4    0.494635
# Name: MI Scores, dtype: float64
# 45 x4    0.50872
# Name: MI Scores, dtype: float64
# 46 x4    0.440958
# Name: MI Scores, dtype: float64
# 47 x4    0.631552
# Name: MI Scores, dtype: float64
# 48 x4    0.549013
# Name: MI Scores, dtype: float64
# 49 x4    0.370605
# Name: MI Scores, dtype: float64
# 50 x4    0.442973
# Name: MI Scores, dtype: float64
# 51 x4    0.605095
# Name: MI Scores, dtype: float64
# 52 x4    0.380141
# Name: MI Scores, dtype: float64
# 53 x4    0.603482
# Name: MI Scores, dtype: float64
# 54 x4    0.490685
# Name: MI Scores, dtype: float64
# 55 x4    0.473454
# Name: MI Scores, dtype: float64
# 56 x4    0.397582
# Name: MI Scores, dtype: float64
# 57 x4    0.618572
# Name: MI Scores, dtype: float64
# 58 x4    0.500801
# Name: MI Scores, dtype: float64
# 59 x4    0.523287
# Name: MI Scores, dtype: float64
# 60 x4    0.349931
# Name: MI Scores, dtype: float64
# 61 x4    0.604041
# Name: MI Scores, dtype: float64
# 62 x4    0.454969
# Name: MI Scores, dtype: float64
# 63 x4    0.582912
# Name: MI Scores, dtype: float64
# 64 x4    0.410436
# Name: MI Scores, dtype: float64
# 65 x4    0.32
# Name: MI Scores, dtype: float64
# 66 x4    0.644554
# Name: MI Scores, dtype: float64
# 67 x4    0.502264
# Name: MI Scores, dtype: float64
# 68 x4    0.44992
# Name: MI Scores, dtype: float64
# 69 x4    0.327598
# Name: MI Scores, dtype: float64
# 70 x4    0.310573
# Name: MI Scores, dtype: float64
# 71 x4    0.300399
# Name: MI Scores, dtype: float64
# 72 x4    0.30787
# Name: MI Scores, dtype: float64
# 73 x4    0.553696
# Name: MI Scores, dtype: float64
# 74 x4    0.424833
# Name: MI Scores, dtype: float64
# 75 x4    0.494473
# Name: MI Scores, dtype: float64
# 76 x4    0.469462
# Name: MI Scores, dtype: float64
# 77 x4    0.31975
# Name: MI Scores, dtype: float64
# 78 x4    0.494788
# Name: MI Scores, dtype: float64
# 79 x4    0.31785
# Name: MI Scores, dtype: float64
# 80 x4    0.379609
# Name: MI Scores, dtype: float64
# 81 x4    0.211912
# Name: MI Scores, dtype: float64
# 82 x4    0.375489
# Name: MI Scores, dtype: float64
# 83 x4    0.354768
# Name: MI Scores, dtype: float64
# 84 x4    0.291637
# Name: MI Scores, dtype: float64
# 85 x4    0.521097
# Name: MI Scores, dtype: float64
# 86 x4    0.372003
# Name: MI Scores, dtype: float64
# 87 x4    0.333899
# Name: MI Scores, dtype: float64
# 88 x4    0.362049
# Name: MI Scores, dtype: float64
# 89 x4    0.377778
# Name: MI Scores, dtype: float64
# 90 x4    0.258745
# Name: MI Scores, dtype: float64
# 91 x4    0.1144
# Name: MI Scores, dtype: float64
# 92 x4    0.502607
# Name: MI Scores, dtype: float64
# 93 x4    0.298491
# Name: MI Scores, dtype: float64
# 94 x4    0.305902
# Name: MI Scores, dtype: float64
# 95 x4    0.449095
# Name: MI Scores, dtype: float64
# 96 x4    0.289691
# Name: MI Scores, dtype: float64
# 97 x4    0.467052
# Name: MI Scores, dtype: float64
# 98 x4    0.265234
# Name: MI Scores, dtype: float64
# 99 x4    0.326174
# Name: MI Scores, dtype: float64
# 100 x4    0.345639
# Name: MI Scores, dtype: float64
# 101 x4    0.349354
# Name: MI Scores, dtype: float64
# 102 x4    0.392796
# Name: MI Scores, dtype: float64
# 103 x4    0.36101
# Name: MI Scores, dtype: float64
# 104 x4    0.260661
# Name: MI Scores, dtype: float64
# 105 x4    0.235901
# Name: MI Scores, dtype: float64
# 106 x4    0.330171
# Name: MI Scores, dtype: float64
# 107 x4    0.17933
# Name: MI Scores, dtype: float64
# 108 x4    0.211919
# Name: MI Scores, dtype: float64
# 109 x4    0.280788
# Name: MI Scores, dtype: float64
# 110 x4    0.223889
# Name: MI Scores, dtype: float64
# 111 x4    0.328439
# Name: MI Scores, dtype: float64
# 112 x4    0.390672
# Name: MI Scores, dtype: float64
# 113 x4    0.527786
# Name: MI Scores, dtype: float64
# 114 x4    0.361003
# Name: MI Scores, dtype: float64
# 115 x4    0.416451
# Name: MI Scores, dtype: float64
# 116 x4    0.557897
# Name: MI Scores, dtype: float64
# 117 x4    0.192513
# Name: MI Scores, dtype: float64
# 118 x4    0.45814
# Name: MI Scores, dtype: float64
# 119 x4    0.434281
# Name: MI Scores, dtype: float64
# 120 x4    0.361295
# Name: MI Scores, dtype: float64
# 121 x4    0.22322
# Name: MI Scores, dtype: float64
# 122 x4    0.441821
# Name: MI Scores, dtype: float64
# 123 x4    0.347754
# Name: MI Scores, dtype: float64
# 124 x4    0.408002
# Name: MI Scores, dtype: float64
# 125 x4    0.157171
# Name: MI Scores, dtype: float64
# 126 x4    0.318578
# Name: MI Scores, dtype: float64
# 127 x4    0.309276
# Name: MI Scores, dtype: float64
# 128 x4    0.271758
# Name: MI Scores, dtype: float64
# 129 x4    0.151551
# Name: MI Scores, dtype: float64
# 130 x4    0.220702
# Name: MI Scores, dtype: float64
# 131 x4    0.366655
# Name: MI Scores, dtype: float64
# 132 x4    0.482888
# Name: MI Scores, dtype: float64
# 133 x4    0.330786
# Name: MI Scores, dtype: float64
# 134 x4    0.244028
# Name: MI Scores, dtype: float64
# 135 x4    0.185143
# Name: MI Scores, dtype: float64
# 136 x4    0.327788
# Name: MI Scores, dtype: float64
# 137 x4    0.348608
# Name: MI Scores, dtype: float64
# 138 x4    0.336399
# Name: MI Scores, dtype: float64
# 139 x4    0.19402
# Name: MI Scores, dtype: float64
# 140 x4    0.318966
# Name: MI Scores, dtype: float64
# 141 x4    0.186763
# Name: MI Scores, dtype: float64
# 142 x4    0.211874
# Name: MI Scores, dtype: float64
# 143 x4    0.408931
# Name: MI Scores, dtype: float64
# 144 x4    0.210628
# Name: MI Scores, dtype: float64
# 145 x4    0.173525
# Name: MI Scores, dtype: float64
# 146 x4    0.447172
# Name: MI Scores, dtype: float64
# 147 x4    0.195509
# Name: MI Scores, dtype: float64
# 148 x4    0.183958
# Name: MI Scores, dtype: float64
# 149 x4    0.318788
# Name: MI Scores, dtype: float64
# 150 x4    0.320309
# Name: MI Scores, dtype: float64
# 151 x4    0.203173
# Name: MI Scores, dtype: float64
# 152 x4    0.300168
# Name: MI Scores, dtype: float64
# 153 x4    0.302198
# Name: MI Scores, dtype: float64
# 154 x4    0.227823
# Name: MI Scores, dtype: float64
# 155 x4    0.230126
# Name: MI Scores, dtype: float64
# 156 x4    0.24713
# Name: MI Scores, dtype: float64
# 157 x4    0.257642
# Name: MI Scores, dtype: float64
# 158 x4    0.302842
# Name: MI Scores, dtype: float64
# 159 x4    0.110685
# Name: MI Scores, dtype: float64
# 160 x4    0.370924
# Name: MI Scores, dtype: float64
# 161 x4    0.099144
# Name: MI Scores, dtype: float64
# 162 x4    0.184015
# Name: MI Scores, dtype: float64
# 163 x4    0.060267
# Name: MI Scores, dtype: float64
# 164 x4    0.33585
# Name: MI Scores, dtype: float64
# 165 x4    0.1686
# Name: MI Scores, dtype: float64
# 166 x4    0.110103
# Name: MI Scores, dtype: float64
# 167 x4    0.284872
# Name: MI Scores, dtype: float64
# 168 x4    0.16772
# Name: MI Scores, dtype: float64
# 169 x4    0.361813
# Name: MI Scores, dtype: float64
# 170 x4    0.136857
# Name: MI Scores, dtype: float64
# 171 x4    0.215659
# Name: MI Scores, dtype: float64
# 172 x4    0.143632
# Name: MI Scores, dtype: float64
# 173 x4    0.289942
# Name: MI Scores, dtype: float64
# 174 x4    0.21966
# Name: MI Scores, dtype: float64
# 175 x4    0.421899
# Name: MI Scores, dtype: float64
# 176 x4    0.175105
# Name: MI Scores, dtype: float64
# 177 x4    0.24589
# Name: MI Scores, dtype: float64
# 178 x4    0.368009
# Name: MI Scores, dtype: float64
# 179 x4    0.26132
# Name: MI Scores, dtype: float64
# 180 x4    0.278353
# Name: MI Scores, dtype: float64
# 181 x4    0.137885
# Name: MI Scores, dtype: float64
# 182 x4    0.210827
# Name: MI Scores, dtype: float64
# 183 x4    0.29275
# Name: MI Scores, dtype: float64
# 184 x4    0.388672
# Name: MI Scores, dtype: float64
# 185 x4    0.37916
# Name: MI Scores, dtype: float64
# 186 x4    0.227491
# Name: MI Scores, dtype: float64
# 187 x4    0.112214
# Name: MI Scores, dtype: float64
# 188 x4    0.140525
# Name: MI Scores, dtype: float64
# 189 x4    0.076782
# Name: MI Scores, dtype: float64
# 190 x4    0.201614
# Name: MI Scores, dtype: float64
# 191 x4    0.06042
# Name: MI Scores, dtype: float64
# 192 x4    0.177719
# Name: MI Scores, dtype: float64
# 193 x4    0.094144
# Name: MI Scores, dtype: float64
# 194 x4    0.087385
# Name: MI Scores, dtype: float64
# 195 x4    0.124658
# Name: MI Scores, dtype: float64
# 196 x4    0.073377
# Name: MI Scores, dtype: float64
# 197 x4    0.361977
# Name: MI Scores, dtype: float64
# 198 x4    0.253586
# Name: MI Scores, dtype: float64
# 199 x4    0.128965
# Name: MI Scores, dtype: float64

# %%
from tqdm import tqdm

H=20
n_epoch = 300
minibatch = 10000

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(1, H)
        self.fc2 = nn.Linear(1, H)
        self.fc3 = nn.Linear(H, 1)

    def forward(self, x, y):
        h1 = F.relu(self.fc1(x)+self.fc2(y))
        h2 = self.fc3(h1)
        return h2  

model = [Net() for i in range(x.shape[1])]
optimizer = [torch.optim.Adam(model[i].parameters(), lr=0.01) for i in range(x.shape[1])]

plot_loss = []

y=y.reshape(-1,1)
print(x.shape)
print(y.shape)

for epoch in tqdm(range(n_epoch)):
    back_loss = torch.zeros(6)
    s = np.random.choice(x.shape[0],minibatch)
    for i in range(x.shape[1]):
        x_sample = Variable(torch.from_numpy(x[s,i].reshape(-1,1)).type(torch.FloatTensor), requires_grad = True)
        y_sample = Variable(torch.from_numpy(y[s]).type(torch.FloatTensor), requires_grad = True)
        y_shuffle = Variable(torch.from_numpy(np.random.permutation(y[s])).type(torch.FloatTensor), requires_grad = True)    
        ret = torch.mean(model[i](x_sample, y_sample)) - torch.log(torch.mean(torch.exp(model[i](x_sample, y_shuffle))))
        loss = - ret  # maximize
        model[i].zero_grad()
        loss.backward()
        optimizer[i].step()
        back_loss[i] = ret

    plot_loss.append(back_loss.data.numpy())


    #back_loss = loss

print('')
print(back_loss)

plot_loss = np.asarray(plot_loss)

plt.plot(plot_loss[:,0])
plt.plot(plot_loss[:,1])
plt.plot(plot_loss[:,2])
plt.plot(plot_loss[:,3])
plt.plot(plot_loss[:,4])
# Out:
# (20000, 6)
# (20000, 1)
# 100%|██████████| 300/300 [00:12<00:00, 24.22it/s]
# tensor([1.4058, 0.7957, 0.5150, 0.2384, 0.3503,    nan], grad_fn=<CopySlices>)

# %%
from tqdm import tqdm

H=50
n_epoch = 1200
minibatch = 10000

class Net(nn.Module):
    def __init__(self,input_dim):
        super(Net, self).__init__()
        self.input_dim = input_dim
        self.fc1 = nn.ModuleList()
        self.fc2 = nn.ModuleList()
        self.fc3 = nn.ModuleList()
        self.fc4 = nn.ModuleList()
        
        for i in range(self.input_dim): 
            self.fc1.append(nn.Linear(1, H))
            self.fc2.append(nn.Linear(1, H))
            self.fc3.append(nn.Linear(1, H))
            self.fc4.append(nn.Linear(H, 1))
            #self.fc4.append(nn.Linear(2, 1))

    def forward(self, x, t, y):
        h = []        
        for i in range(self.input_dim):
            h0 = F.relu(self.fc1[i](x[:,i].reshape(-1,1)) + 
                        self.fc2[i](t) + 
                        self.fc3[i](y))
            #h1 = self.fc3[i](torch.cat((h0, x[:,-1].reshape(-1,1)), 1) )
            #h2 = self.fc3[i](torch.cat((h0, x[:,-1].reshape(-1,1)), 1) )
            h1 = self.fc4[i](h0)
            h.append(h1)

        return torch.cat(h, dim=1)  

model = Net(x.shape[1]-1) # -1 은 t차원을 제외한 것...
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)

plot_loss = []
chunk_loss = []
di = []
y=y.reshape(-1,1)
print(x.shape)
print(y.shape)

chunk_size = 200

for chunk in tqdm(range(int(x.shape[0]/chunk_size))):
    for epoch in range(30):
        #i = epoch%100
        s = [*range(chunk*chunk_size,chunk*chunk_size+chunk_size)]  
        #s = np.random.choice(x.shape[0],minibatch)
        x_sample = Variable(torch.from_numpy(x[s,0:5]).type(torch.FloatTensor), requires_grad = True)
        t_sample = Variable(torch.from_numpy(x[s,5].reshape(-1,1)).type(torch.FloatTensor), requires_grad = True)
        y_sample = Variable(torch.from_numpy(y[s]).type(torch.FloatTensor), requires_grad = True)
        y_shuffle = Variable(torch.from_numpy(np.random.permutation(y[s])).type(torch.FloatTensor), requires_grad = True)    
        p_xy = model(x_sample, t_sample, y_sample)
        p_x_y = model(x_sample, t_sample, y_shuffle)
        ret = torch.mean(p_xy,0) - torch.log(torch.mean(torch.exp(p_x_y),0))
        loss = - ret  # maximize

        model.zero_grad()
        #loss.retain_grad()
        #t_sample.retain_grad()
        loss.mean().backward()
        optimizer.step()

        plot_loss.append(-loss.data.numpy())

        #print(torch.mean(p_xy[:,4]))
        #dx = torch.autograd.grad(loss[4], t_sample)
        #print(p_xy.grad) #x_sample[-1,:].grad)

        di.append(torch.mean(t_sample.grad).data.numpy())
        #back_loss = loss
        #if i == 99:
        #    print(loss[4])
    #chunk_loss.append(-loss.data.numpy())

#print(torch.mean(x_sample.grad,0))

plot_loss = np.asarray(plot_loss)
df_loss = pd.DataFrame(plot_loss,columns=['x0','x1','x2','x3','x4'])
#df_loss.rolling(window=5).mean().plot()

di = np.asarray(di)
#print(mi_scores)
print(np.mean(plot_loss[200:,:],0))

plt.figure(figsize=(30,8))
plt.plot(di)
plt.show()
#print(np.mean(di[200:,0],0))

#print(x_sample.grad)
plt.figure(figsize=(30,8))
plt.plot(plot_loss[:,0:5])
plt.show()
'''
chunk_loss = np.asarray(chunk_loss)
plt.figure(figsize=(30,8))
plt.plot(chunk_loss[:,0:4])
plt.show()
'''
# Out:
# (20000, 6)
# (20000, 1)
# 100%|██████████| 100/100 [00:23<00:00,  4.32it/s]
# [1.2863057  0.7494392  0.48342228 0.23139572 0.3442548 ]
# '\nchunk_loss = np.asarray(chunk_loss)\nplt.figure(figsize=(30,8))\nplt.plot(chunk_loss[:,0:4])\nplt.show()\n'

# %%
print(torch.mean(model.fc2[0].weight))
print(torch.mean(model.fc2[1].weight))
print(torch.mean(model.fc2[2].weight))
print(torch.mean(model.fc2[3].weight))
print(torch.mean(model.fc2[4].weight))
# Out:
# tensor(-0.1304, grad_fn=<MeanBackward0>)
# tensor(-0.1315, grad_fn=<MeanBackward0>)
# tensor(-0.1638, grad_fn=<MeanBackward0>)
# tensor(-0.1484, grad_fn=<MeanBackward0>)
# tensor(-0.0393, grad_fn=<MeanBackward0>)

# %%
print(torch.sum(model.fc2[0].weight))
print(torch.sum(model.fc2[1].weight))
print(torch.sum(model.fc2[2].weight))
print(torch.sum(model.fc2[3].weight))
print(torch.sum(model.fc2[4].weight))
# Out:
# tensor(-6.5213, grad_fn=<SumBackward0>)
# tensor(-6.5767, grad_fn=<SumBackward0>)
# tensor(-8.1918, grad_fn=<SumBackward0>)
# tensor(-7.4181, grad_fn=<SumBackward0>)
# tensor(-1.9675, grad_fn=<SumBackward0>)

# %%
x_sample = Variable(torch.from_numpy(x[:,0:5]).type(torch.FloatTensor), requires_grad = True)
t_sample = Variable(torch.from_numpy(x[:,5].reshape(-1,1)).type(torch.FloatTensor), requires_grad = True)
y_sample = Variable(torch.from_numpy(y[:]).type(torch.FloatTensor), requires_grad = True)
y_shuffle = Variable(torch.from_numpy(np.random.permutation(y[:])).type(torch.FloatTensor), requires_grad = True)    
p_xy = model(x_sample, t_sample, y_sample)
p_x_y = model(x_sample, t_sample, y_shuffle)
ret = torch.mean(p_xy,0) - torch.log(torch.mean(torch.exp(p_x_y),0))
loss = - ret  # maximize
print(loss)
dx4 = torch.autograd.grad(loss[4], t_sample)[0]

print(torch.mean(dx4))
# Out:
# tensor([-0.2234, -0.5616, -0.2123, -0.0412, -0.1012], grad_fn=<NegBackward0>)
# tensor(-3.1038e-07)

# %%
# Out:
# tensor([-1.4398e-06])

# %%
plot_loss = np.asarray(plot_loss)
df_loss = pd.DataFrame(plot_loss,columns=['x0','x1','x2','x3','x4'])
df_sloss = df_loss.rolling(window=30).mean()
df_sloss.plot(figsize=(30,8))

print(np.mean(np.gradient(df_sloss[200:]['x0'].values)))
print(np.mean(np.gradient(df_sloss[200:]['x1'].values)))
print(np.mean(np.gradient(df_sloss[200:]['x2'].values)))
print(np.mean(np.gradient(df_sloss[200:]['x3'].values)))
print(np.mean(np.gradient(df_sloss[200:]['x4'].values)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-60e0040cdf68> in <module>
#       1 plot_loss = np.asarray(plot_loss)
# ----> 2 df_loss = pd.DataFrame(plot_loss,columns=['x0','x1','x2','x3','x4'])
#       3 df_sloss = df_loss.rolling(window=30).mean()
#       4 df_sloss.plot(figsize=(30,8))
#       5
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     670                 )
#     671             else:
# --> 672                 mgr = ndarray_to_mgr(
#     673                     data,
#     674                     index,
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/construction.py in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     322     )
#     323
# --> 324     _check_values_indices_shape_match(values, index, columns)
#     325
#     326     if typ == "array":
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/construction.py in _check_values_indices_shape_match(values, index, columns)
#     391         passed = values.shape
#     392         implied = (len(index), len(columns))
# --> 393         raise ValueError(f"Shape of passed values is {passed}, indices imply {implied}")
#     394
#     395
#
# ValueError: Shape of passed values is (300, 6), indices imply (300, 5)

# %%
df_sloss

# %%
print(np.mean(di[200:,:],0))
plt.figure(figsize=(30,8))
plt.plot(di[:,4])
plt.show()

# %%
di

# %% [markdown]
# + 편미분 Test

# %%
def uc(a,b):
    return a*b[0] + b[1]

# %%
x = torch.tensor(100.0, requires_grad=True)
t = torch.tensor(2.0, requires_grad=True)
print(x)
print(t)
u = x**2 * t
print(u)
# 1st derivatives
#dt = torch.autograd.grad(u, t)[0]
#print(dt)
dx = torch.autograd.grad(u, x,create_graph=True)[0]
print(dx)
# 2nd derivatives (higher orders require `create_graph=True`)
ddx = torch.autograd.grad(dx, x)[0]
print(ddx)

# %%
tx = torch.tensor([*range(200)],dtype=float, requires_grad=True)
ty = tx * torch.normal(1.0,0.5,size=(200,))
dx = torch.autograd.grad(torch.sum(ty), tx)[0]
print(np.mean(dx.tolist()))

# %%
plt.plot(ty.detach().numpy(),'.')

# %%
a = torch.rand(10, requires_grad=True)
b = torch.rand(10, requires_grad=True)

output = (2 * a).sum()

c = torch.autograd.grad(output, (a, b),allow_unused=True)
c

# %%
aa = np.random.rand(3,3)
aa

# %%
aa[:,[1,-1]]
